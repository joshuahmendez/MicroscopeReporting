# %%
# Importing modules
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Defening path to data files
pathToData = r'C:\Users\legion1k\OneDrive - New York Structural Biology Center\SEMC\DataCollectionStats\AllDataCompiledForPython.xlsx'

# %%
# Reading data from file
df_dict = pd.read_excel(pathToData, sheet_name=None)
keys1 = list(df_dict.keys())

# %%
# Separating each sheet to its own dataframe for each center

# Ice Thickness
columnName = df_dict[keys1[0]].iloc[0,0:4] #name for the columns

dfIce_MEMC = df_dict[keys1[0]].iloc[1:,0:4].dropna() 
dfIce_MEMC.columns = columnName

dfIce_EMG = df_dict[keys1[0]].iloc[1:,4:8].dropna()
dfIce_EMG.columns = columnName

dfIce_NC = df_dict[keys1[0]].iloc[1:,8:12].dropna()
dfIce_NC.columns = columnName

# Defocus
columnName = df_dict[keys1[1]].iloc[0,0:6] #name for the columns

dfDef_MEMC = df_dict[keys1[1]].iloc[1:,0:6].dropna()
dfDef_MEMC.columns = columnName

dfDef_EMG = df_dict[keys1[1]].iloc[1:,6:12].dropna()
dfDef_EMG.columns =  columnName

dfDef_NC = df_dict[keys1[1]].iloc[1:,12:18].dropna()
dfDef_NC.columns = columnName
dfDef_NC

# Images per hour
columnName = df_dict[keys1[2]].iloc[0,0:2] #name for the columns

dfImg_MEMCenn = df_dict[keys1[2]].iloc[1:,0:2].dropna()
dfImg_MEMCenn.columns = columnName

dfImg_MEMCesn = df_dict[keys1[2]].iloc[1:,2:4].dropna()
dfImg_MEMCesn.columns = columnName

dfImg_EMGenn = df_dict[keys1[2]].iloc[1:,4:6].dropna()
dfImg_EMGenn.columns = columnName

dfImg_EMGesn = df_dict[keys1[2]].iloc[1:,6:8].dropna()
dfImg_EMGesn.columns = columnName

dfImg_NCenn = df_dict[keys1[2]].iloc[1:,8:10].dropna()
dfImg_NCenn.columns = columnName

dfImg_NCesn = df_dict[keys1[2]].iloc[1:,10:12].dropna()
dfImg_NCesn.columns = columnName

dfImg_NCeer = df_dict[keys1[2]].iloc[1:,12:14].dropna()
dfImg_NCeer.columns = columnName
"""
#Length of sessions
columnName = df_dict[keys1[3]].iloc[0,0] #name for the columns

dfLen_MEMC = pd.to_timedelta(df_dict[keys1[3]].iloc[1:,0].dropna())
# dfLen_MEMC = pd.to_datetime(dfLen_MEMC, format='%H:%M:%S').to_frame(name=columnName)
dfLen_EMG = df_dict[keys1[3]].iloc[1:,1].dropna().to_frame(name=columnName)
dfLen_NC = df_dict[keys1[3]].iloc[1:,2].dropna().to_frame(name=columnName)

# df_dict[keys1[3]].iloc[1]
dfLen_MEMC
# columnName """
# Out:
# "\n#Length of sessions\ncolumnName = df_dict[keys1[3]].iloc[0,0] #name for the columns\n\ndfLen_MEMC = pd.to_timedelta(df_dict[keys1[3]].iloc[1:,0].dropna())\n# dfLen_MEMC = pd.to_datetime(dfLen_MEMC, format='%H:%M:%S').to_frame(name=columnName)\ndfLen_EMG = df_dict[keys1[3]].iloc[1:,1].dropna().to_frame(name=columnName)\ndfLen_NC = df_dict[keys1[3]].iloc[1:,2].dropna().to_frame(name=columnName)\n\n# df_dict[keys1[3]].iloc[1]\ndfLen_MEMC\n# columnName "

# %%
# Plotting of the ice thickness
sns.displot(data=dfIce_MEMC, x="Average Thickness")
sns.displot(data=dfIce_EMG, x="Average Thickness")
sns.displot(data=dfIce_NC, x="Average Thickness")
# Out:
# c:\Users\legion1k\miniconda3\envs\jupyterlab\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\legion1k\miniconda3\envs\jupyterlab\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\legion1k\miniconda3\envs\jupyterlab\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
